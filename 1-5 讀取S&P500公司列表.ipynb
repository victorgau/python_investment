# %% [markdown]
# <a href="https://colab.research.google.com/github/victorgau/python_investment/blob/master/1-5%20%E8%AE%80%E5%8F%96S%26P500%E5%85%AC%E5%8F%B8%E5%88%97%E8%A1%A8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 讀取S&P500公司列表

# %%
import pandas as pd

# %%
url = "https://en.wikipedia.org/wiki/List_of_S%26P_500_companies"

# %%
dfs = pd.read_html(url)

# %%
dfs[0]

# %% [markdown]
# <a href="https://colab.research.google.com/github/victorgau/python_investment/blob/master/8-1%20%E5%9D%87%E7%B7%9A%20(MA).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 均線 (MA)

# %%
import pandas as pd
import pandas_datareader.data as web

# %%
# 讀取從指定日期之後的股價資訊
df = web.DataReader("TSLA", 'yahoo', "2018-01-01")

# %% [markdown]
# ## 畫出均線

# %%
# 作法一
df['20d'] = pd.Series.rolling(df['Adj Close'], window=20).mean()
df['60d'] = pd.Series.rolling(df['Adj Close'], window=60).mean()

# %%
# 作法二
df['5d'] = df['Adj Close'].rolling(window=5).mean()
df['120d'] = df['Adj Close'].rolling(window=120).mean()

# %%
df[['Adj Close','20d','60d']].plot(grid=True, figsize=(10,8))

# %% [markdown]
# <a href="https://colab.research.google.com/github/victorgau/python_investment/blob/master/6-4%20%E8%A8%88%E7%AE%97%E9%81%8E%E5%8E%BBN%E5%B9%B4%E7%9A%84%E6%8A%95%E8%B3%87%E5%A0%B1%E9%85%AC%E7%8E%87.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 計算投資報酬率

# %%
import pandas_datareader.data as web

# %%
start = "2017-01-01"
end = "2017-12-31"

# %%
# 讀取從指定期間的股價歷史資料
df = web.DataReader("0050.tw", 'yahoo', start, end)

# %%
df['Adj Close'][-1]/df['Adj Close'][0]

# %% [markdown]
# ---

# %% [markdown]
# ## 計算過去 N 年的投資報酬率

# %%
from datetime import datetime, timedelta

# %%
N = 3

# %%
start = datetime.now() - timedelta(days=365*N)

# %%
df = web.DataReader("2330.tw", 'yahoo', start)

# %%
df['Adj Close'][-1] / df['Adj Close'][0]

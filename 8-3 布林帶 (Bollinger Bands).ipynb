# %% [markdown]
# <a href="https://colab.research.google.com/github/victorgau/python_investment/blob/master/8-3%20%E5%B8%83%E6%9E%97%E5%B8%B6%20(Bollinger%20Bands).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 繪製 BBands

# %%
import pandas as pd
import pandas_datareader.data as web

# %%
# 讀取從指定日期之後的股價資訊
df = web.DataReader("TSLA", "yahoo", "2018-01-01")

# %% [markdown]
# ## 畫出BBands

# %%
# bbands策略,N=20
df['20ma'] = pd.Series.rolling(df['Adj Close'], window=20).mean()
df['std'] = pd.Series.rolling(df['Adj Close'], window=20).std()
# 上軌=20ma+1.5sd ,中軌=20ma, 下軌=20ma-1.5sd
df['ubb'] = df['20ma'] + 1.5*df['std']
df['mbb'] = df['20ma']
df['lbb'] = df['20ma'] - 1.5*df['std']

# %%
df[['Adj Close','ubb','mbb', 'lbb']].plot(grid=True, figsize=(10,8))

# %% [markdown]
# <a href="https://colab.research.google.com/github/victorgau/python_investment/blob/master/0-4%20Python%E7%9A%84%E8%BF%B4%E5%9C%88.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Python 迴圈

# %% [markdown]
# ## 複習重點：
#
# * for loop
# * break 跟 continue
# * while loop

# %% [markdown]
# ---

# %% [markdown]
# ## for 迴圈
#
# ### 語法：
#
# ```python
# for 變數 in 資料結構:
#     欲執行之程式區塊
# ```

# %%
# for 迴圈

A = range(5)

for i in A:
    print(i)

# %% [markdown]
# ## 關於 range

# %%
# %%python2
#
# a = range(10)
# print(type(a))
# print(a)

# %%
b = range(10)
print(type(b))
print(b)

# %%
range?

# %%
# for 迴圈
A = range(1,10, 2)

for i in A:    # enumerate: iterator
    print(i)

# %%
# for 迴圈
A = range(1,10, 2)

for i in enumerate(A):    # enumerate: iterator
    print(i)

# %%
# for 迴圈
A = range(1,10, 2)

for i, item in enumerate(A):    # enumerate: iterator
    print(i,"==>",item)

# %% [markdown]
# ## 【練習】
#
# 使用 for 迴圈畫出一個金字塔！
#
#         *
#        ***
#       *****
#      *******
#     *********

# %%
'*' * 10

# %%
for i in range(5):
  print(' '*(5-i)+'*'*(2*i+1))

# %% [markdown]
# ---

# %% [markdown]
# ## break 跟 continue
#
# * break 用來跳出迴圈
# * continue 用來繼續執行迴圈的下一輪迴

# %%
for i in range(1, 10):
    print(i)

# %%
for i in range(1, 10):
    if i % 5 == 0:
        break
    print(i)

# %%
for i in range(1, 10):
    if i % 5 == 0:
        continue
    print(i)

# %% [markdown]
# ---

# %% [markdown]
# ## 巢狀迴圈

# %%
for i in range(5):
    for j in range(5):
        print("i =", i, ", j =", j)

# %% [markdown]
# ## 【練習】
#
# 請用巢狀迴圈，列出九九乘法表！

# %% [markdown]
# ---

# %% [markdown]
# ## while 迴圈
#
# ### 語法：
#
# ```python
# while 條件式:
#     欲執行之程式區塊
# ```

# %%
# while 迴圈

count = 0
while (count < 10):
    print(count)
    count += 1

# %%
# while 迴圈

count = 0
while (count < 10):
    if count % 2 == 0:
        count += 1
        continue
    print(count)
    count += 1

# %%
# while 迴圈

count = 0
while (count < 10):
    if count % 2 != 0:
        print(count)
    count += 1

# %%
# while 迴圈

count = 0
while (count < 10):
    count += 1
    if count % 2 == 0:
        break
    print(count)

# %%
# while 迴圈

count = 0
while (count < 10):
    if count % 3 == 0:
        print(count)
    count += 1

# %%
count = 0
while True:
    if count > 10:
        break
    count += 1
